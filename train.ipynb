# %%
cd /content/drive/MyDrive/ImageClassification-using-MobileNet
# Out:
# /content/drive/MyDrive/ImageClassification-using-MobileNet

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers import Adam, SGD, Adadelta
import matplotlib.pyplot as plt
import os
from models import *
from config import *
from preprocess import DataGenerator

# %%
# -----> preprocess data

train_data, val_data, label_map  = DataGenerator()
np.save('label_map.npy', label_map)
# Out:
# Found 1683 images belonging to 5 classes.
# Found 419 images belonging to 5 classes.

# %% [markdown]
# ### MobileNetV2

# %%
# -----> load mode, compile and fit - MobileNetV2

model = Models()
model = model.mobilenetV2()


model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                             metrics=['accuracy'])

callbacks =[
    tf.keras.callbacks.EarlyStopping(patience = 20)
          ]
          
history = model.fit(train_data,
          steps_per_epoch=train_data.samples / batch_size, 
          validation_data=val_data,
          validation_steps=val_data.samples / batch_size,
          epochs=100,
         )


model.save("weights/mobilenetV2.h5")
# Out:
# ...
# 9420800/9406464 [==============================] - 0s 0us/step
# Epoch 1/100
# 105/105 [==============================] - 43s 382ms/step - loss: 1.5852 - accuracy: 0.4462 - val_loss: 1.2350 - val_accuracy: 0.5513
# Epoch 2/100
# 105/105 [==============================] - 39s 373ms/step - loss: 0.7963 - accuracy: 0.7201 - val_loss: 0.9826 - val_accuracy: 0.6492
# Epoch 3/100
# 105/105 [==============================] - 39s 373ms/step - loss: 0.5793 - accuracy: 0.7908 - val_loss: 0.9140 - val_accuracy: 0.6683
# Epoch 4/100
# 105/105 [==============================] - 39s 373ms/step - loss: 0.4591 - accuracy: 0.8366 - val_loss: 1.0144 - val_accuracy: 0.6444
# Epoch 5/100
# 105/105 [==============================] - 39s 371ms/step - loss: 0.3787 - accuracy: 0.8592 - val_loss: 0.9787 - val_accuracy: 0.6635
# Epoch 6/100
# 105/105 [==============================] - 39s 371ms/step - loss: 0.2758 - accuracy: 0.8990 - val_loss: 0.9201 - val_accuracy: 0.6874
# Epoch 7/100
# ...

# %%
# "acc"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# ### ResNet50V2

# %%
# -----> load mode, compile and fit  - ResNet50V2

model = Models()
model = model.resnet50V2()


model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                             metrics=['accuracy'])

callbacks =[
    tf.keras.callbacks.EarlyStopping(patience = 20)
          ]
          
history = model.fit(train_data,
          steps_per_epoch=train_data.samples / batch_size, 
          validation_data=val_data,
          validation_steps=val_data.samples / batch_size,
          epochs=50,
         )

model.save("weights/resnet50V2.h5")
# Out:
# ...
# 94683136/94668760 [==============================] - 1s 0us/step
# Epoch 1/50
# 105/105 [==============================] - 580s 5s/step - loss: 3.9243 - accuracy: 0.3072 - val_loss: 2.8077 - val_accuracy: 0.3604
# Epoch 2/50
# 105/105 [==============================] - 39s 369ms/step - loss: 2.1462 - accuracy: 0.4700 - val_loss: 2.2017 - val_accuracy: 0.4368
# Epoch 3/50
# 105/105 [==============================] - 39s 372ms/step - loss: 1.6990 - accuracy: 0.5157 - val_loss: 1.7692 - val_accuracy: 0.5036
# Epoch 4/50
# 105/105 [==============================] - 39s 369ms/step - loss: 1.3539 - accuracy: 0.5865 - val_loss: 1.8368 - val_accuracy: 0.4726
# Epoch 5/50
# 105/105 [==============================] - 39s 367ms/step - loss: 1.1678 - accuracy: 0.6257 - val_loss: 1.5555 - val_accuracy: 0.5465
# Epoch 6/50
# 105/105 [==============================] - 39s 368ms/step - loss: 1.0792 - accuracy: 0.6453 - val_loss: 1.4377 - val_accuracy: 0.5489
# Epoch 7/50
# ...

# %%
# "acc"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# ### inceptionV3

# %%
# -----> load mode, compile and fit  - inceptionV3

model = Models()
model = model.inceptionV3()


model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                             metrics=['accuracy'])

callbacks =[
    tf.keras.callbacks.EarlyStopping(patience = 20)
          ]
          
history = model.fit(train_data,
          steps_per_epoch=train_data.samples / batch_size, 
          validation_data=val_data,
          validation_steps=val_data.samples / batch_size,
          epochs=100,
         )


model.save("weights/inceptionV3.h5")
# Out:
# ...
# 87924736/87910968 [==============================] - 1s 0us/step
# Epoch 1/100
# 105/105 [==============================] - 824s 8s/step - loss: 1.8287 - accuracy: 0.3001 - val_loss: 1.5921 - val_accuracy: 0.3866
# Epoch 2/100
# 105/105 [==============================] - 42s 403ms/step - loss: 1.4330 - accuracy: 0.4314 - val_loss: 1.4341 - val_accuracy: 0.4368
# Epoch 3/100
# 105/105 [==============================] - 42s 398ms/step - loss: 1.2859 - accuracy: 0.4765 - val_loss: 1.4222 - val_accuracy: 0.4726
# Epoch 4/100
# 105/105 [==============================] - 42s 396ms/step - loss: 1.2052 - accuracy: 0.5294 - val_loss: 1.2864 - val_accuracy: 0.5107
# Epoch 5/100
# 105/105 [==============================] - 42s 397ms/step - loss: 1.1244 - accuracy: 0.5680 - val_loss: 1.2495 - val_accuracy: 0.5060
# Epoch 6/100
# 105/105 [==============================] - 42s 397ms/step - loss: 1.0727 - accuracy: 0.5829 - val_loss: 1.2497 - val_accuracy: 0.5084
# Epoch 7/100
# ...

# %%
# "acc"
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()

# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
plt.show()
